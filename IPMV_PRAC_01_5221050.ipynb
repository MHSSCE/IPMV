# %% [markdown]
# <a href="https://colab.research.google.com/github/MHSSCE/IPMV/blob/main/IPMV_PRAC_01_5221050.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# M. MEHBOOB N. MEGHANI
#
# 5221050
#
# 46
#
# T. E. EXTC

# %% [markdown]
# Importing Required Packages

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
from io import BytesIO
from PIL import Image
from google.colab import files
from skimage import color, io

# %% [markdown]
# Uploading Image Files to Experiment on it!

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-523e8266-32ce-4bdb-8067-d79755dd2e76" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-523e8266-32ce-4bdb-8067-d79755dd2e76">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving photo-1597655601841-214a4cfe8b2c.jpg to photo-1597655601841-214a4cfe8b2c.jpg

# %% [markdown]
# Loading Uploaded Image

# %%
im = cv2.imread("/content/photo-1597655601841-214a4cfe8b2c.jpg")
cv2_imshow(im)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x843 at 0x7F79F32C8F10>

# %% [markdown]
# Changing Image Color to Gray!

# %%
im3 = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
cv2_imshow(im3)
# Out:
# <PIL.Image.Image image mode=L size=1000x843 at 0x7F79F0C81AD0>

# %% [markdown]
# Changing Image Color to Negative

# %%
neg_img = 255-im3
cv2_imshow(neg_img)
# Out:
# <PIL.Image.Image image mode=L size=1000x843 at 0x7F79FCF10D10>

# %% [markdown]
# Altering Image Color using Numpy Log from here Onwards

# %%
fig = plt.figure()
plt.show()

# %%
c = 255/np.log(1*np.max(im3))

# %%
log_img = c*(np.log(im3+1))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.

# %%
cv2_imshow(log_img)
# Out:
# <PIL.Image.Image image mode=L size=1000x843 at 0x7F79FCF10ED0>
