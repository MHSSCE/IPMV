# %% [markdown]
# <a href="https://colab.research.google.com/github/MHSSCE/IPMV/blob/main/IPMV_PRAC_08_5221050.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MEHBOOB MEGHANI
#
# 5221050
#
# 46

# %%
import cv2
import numpy as np
import random
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
from io import BytesIO
from PIL import Image
from google.colab import files
from skimage import color
from skimage import io
#uploaded = files.upload()
from PIL import ImageDraw
from PIL import ImageFont
from skimage.util import random_noise
figsize=(10,10)

# %% [markdown]
# OPENING

# %%
#FOR OPENING
img=np.zeros([100,100])
img[10:30,10:30]=1;
img[10:30,51:70]=1;
img[31:50,31:50]=1;
img[31:50,71:90]=1;
img[30,30]=1;
img[30,50]=1;
img[30,70]=1;
plt.figure(figsize=figsize)
plt.imshow(img,cmap="gray",vmin=0, vmax=1)
plt.title("Original image")
plt.show()

# %%
m=img.shape[0]
n=img.shape[1]
mask=np.array([[1,1,1],[1,1,1],[1,1,1]])
img1=np.zeros([m,n])
for i in range (1,m-1):
  for j in range(1,n-1):
    temp=[img[i-1, j-1]*mask[0, 0],img[i-1, j]*mask[0, 1],img[i-1, j + 1]*mask[0, 2],img[i, j-1]*mask[1, 0], img[i, j]*mask[1, 1],img[i, j + 1]*mask[1, 2],img[i + 1, j-1]*mask[2, 0],img[i + 1, j]*mask[2, 1],img[i + 1, j + 1]*mask[2, 2]]
    img1[i,j]=min(temp)

plt.figure(figsize=figsize)
plt.imshow(img1,cmap='gray',vmin=0,vmax=1)
plt.title('EROSION')
plt.show()

# %%
m=img.shape[0]
n=img.shape[1]
mask=np.array([[1,1,1],[1,1,1],[1,1,1]])
img2=np.zeros([m,n])
for i in range (1,m-1):
  for j in range(1,n-1):
    temp=[img1[i-1, j-1]*mask[0, 0],img1[i-1, j]*mask[0, 1],img1[i-1, j + 1]*mask[0, 2],img1[i, j-1]*mask[1, 0],img1[i, j]*mask[1, 1],img1[i, j + 1]*mask[1, 2],img1[i + 1, j-1]*mask[2, 0],img1[i + 1, j]*mask[2, 1],img1[i + 1, j + 1]*mask[2, 2]]
    img2[i,j]=max(temp)
    
                #img_new= convolution(mas=mask,im=img)
plt.figure(figsize=figsize)
plt.imshow(img2,cmap='gray',vmin=0,vmax=1)
plt.title('DILATION')
plt.show()

# %% [markdown]
# CLOSING

# %%
#FOR CLOSING
im=np.zeros([100,100])
im[10:30,10:30]=1;
im[10:30,51:70]=1;
im[29:50,31:50]=1;
im[29:50,71:90]=1;

plt.figure(figsize=figsize)
plt.imshow(img,cmap="gray",vmin=0, vmax=1)
plt.title("Original image")
plt.show()

# %%
m=im.shape[0]
n=im.shape[1]
mask=np.array([[1,1,1],[1,1,1],[1,1,1]])
im1=np.zeros([m,n])
for i in range (1,m-1):
  for j in range(1,n-1):
    temp=[im[i-1, j-1]*mask[0, 0],im[i-1, j]*mask[0, 1],im[i-1, j + 1]*mask[0, 2],im[i, j-1]*mask[1, 0],im[i, j]*mask[1, 1],im[i, j + 1]*mask[1, 2],im[i + 1, j-1]*mask[2, 0],im[i + 1, j]*mask[2, 1],im[i + 1, j + 1]*mask[2, 2]]
    im1[i,j]=max(temp)
    
plt.figure(figsize=figsize)
plt.imshow(im1,cmap='gray',vmin=0,vmax=1)
plt.title('DILATION')
plt.show()

# %%
m=im.shape[0]
n=im.shape[1]
mask=np.array([[1,1,1],[1,1,1],[1,1,1]])
im2=np.zeros([m,n])
for i in range (1,m-1):
  for j in range(1,n-1):
    temp=[im[i-1, j-1]*mask[0, 0],im[i-1, j]*mask[0, 1],im[i-1, j + 1]*mask[0, 2],im[i, j-1]*mask[1, 0],im[i, j]*mask[1, 1],im[i, j + 1]*mask[1, 2],im[i + 1, j-1]*mask[2, 0],im[i + 1, j]*mask[2, 1],im[i + 1, j + 1]*mask[2, 2]]
    im2[i,j]=min(temp)
    
plt.figure(figsize=figsize)
plt.imshow(im2,cmap='gray',vmin=0,vmax=1)
plt.title('EROSION')
plt.show()
