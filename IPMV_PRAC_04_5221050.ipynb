# %% [markdown]
# <a href="https://colab.research.google.com/github/MHSSCE/IPMV/blob/main/IPMV_PRAC_04_5221050.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import random
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
from io import BytesIO
from PIL import Image
from google.colab import files
from skimage import color
from skimage import io
#uploaded = files.upload()
from PIL import ImageDraw
from PIL import ImageFont
from skimage.util import random_noise
figsize=(10,10)

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-18cd12be-6425-4286-9150-900f986b478d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-18cd12be-6425-4286-9150-900f986b478d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving download.png to download.png

# %%
im=cv2.imread("/content/download.png")
img=cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=figsize)
plt.imshow(img,cmap="gray",vmin=0, vmax=256)
plt.title("Original image")
plt.show()

# %%
img1=cv2.imread("/content/download.png",0)
#Generate Gaussian noise
gauss = np.random.normal(0,1,img1.size)
gauss = gauss.reshape(img1.shape[0],img1.shape[1]).astype('uint8')
#Add the Gaussian noise to the image 
im2 = cv2.add(img1,gauss)
plt.figure(figsize=figsize)
plt.imshow(im2,cmap="gray",vmin=0, vmax=256)
plt.title("Gaussian Noisy image")
plt.show()

# %%
img1=cv2.imread("/content/download.png",0)
#Generate Gussian noise
gauss = np.random.normal(0,1,img1.size)
gauss = gauss.reshape(img1.shape[0],img1.shape[1]).astype('uint8')
im2 = cv2.add(img1,gauss)

#print(n)
# Develop Averaging filter(3, 3) mask 
mask = np.ones([3, 3], dtype = int)
mask = mask / 9 
mask
# Out:
# array([[0.11111111, 0.11111111, 0.11111111],
#        [0.11111111, 0.11111111, 0.11111111],
#        [0.11111111, 0.11111111, 0.11111111]])

# %%
img1=cv2.imread("/content/download.png",0)
#Generate Gussian noise
gauss = np.random.normal(0,1,img1.size)
gauss = gauss.reshape(img1.shape[0],img1.shape[1]).astype('uint8')
im2 = cv2.add(img1,gauss)

#print(n)
# Develop Averaging filter(3, 3) mask 
mask = np.ones([3, 3], dtype = int)
mask = mask / 9 
img=im2
m= img.shape[0]
n= img.shape[1]
print(m)
print(n)
# Out:
# 843
# 1000
